# %%
import pandas as pd
import os

# %%
df = pd.read_csv("kalimati_tarkari_dataset_cleaned.csv")
df.head()
# Out:
#    SN            Commodity        Date Unit  Minimum  Maximum  Average
# 0   0   Tomato Big(Nepali)  2013-06-16   Kg     35.0     40.0     37.5
# 1   1  Tomato Small(Local)  2013-06-16   Kg     26.0     32.0     29.0
# 2   2           Potato Red  2013-06-16   Kg     20.0     21.0     20.5
# 3   3         Potato White  2013-06-16   Kg     15.0     16.0     15.5
# 4   4   Onion Dry (Indian)  2013-06-16   Kg     28.0     30.0     29.0

# %%
df2= df.pivot_table(index = ['Commodity'], aggfunc ='size')
df2.head()
# Out:
# Commodity
# Apple(Fuji)       395
# Apple(Jholey)    2683
# Arum             2020
# Asparagus        1055
# Bakula           1131
# dtype: int64

# %%
df['count'] = df.groupby('Commodity')['Commodity'].transform('count')
df.head()
# Out:
#    SN            Commodity        Date Unit  Minimum  Maximum  Average  count
# 0   0   Tomato Big(Nepali)  2013-06-16   Kg     35.0     40.0     37.5   2507
# 1   1  Tomato Small(Local)  2013-06-16   Kg     26.0     32.0     29.0   2741
# 2   2           Potato Red  2013-06-16   Kg     20.0     21.0     20.5   2746
# 3   3         Potato White  2013-06-16   Kg     15.0     16.0     15.5   2381
# 4   4   Onion Dry (Indian)  2013-06-16   Kg     28.0     30.0     29.0   2742

# %%
#     print(pd.unique(df['Commodity']))

# %%
df['Product'] = df['Commodity'].apply(lambda x: x.split("(")[0])
df.head()
# Out:
#    SN            Commodity        Date Unit  Minimum  Maximum  Average  count  \
# 0   0   Tomato Big(Nepali)  2013-06-16   Kg     35.0     40.0     37.5   2507
# 1   1  Tomato Small(Local)  2013-06-16   Kg     26.0     32.0     29.0   2741
# 2   2           Potato Red  2013-06-16   Kg     20.0     21.0     20.5   2746
# 3   3         Potato White  2013-06-16   Kg     15.0     16.0     15.5   2381
# 4   4   Onion Dry (Indian)  2013-06-16   Kg     28.0     30.0     29.0   2742
#
#         Product
# 0    Tomato Big
# 1  Tomato Small
# 2    Potato Red
# 3  Potato White
# 4    Onion Dry

# %%
del df['Minimum'] 
del df['Commodity']
del df['Unit']
del df['count']

# %%
df['Weight(kg)'] = pd.to_numeric(df['Average'])
df.head()
# Out:
#    SN        Date  Maximum  Average       Product  Weight(kg)
# 0   0  2013-06-16     40.0     37.5    Tomato Big        37.5
# 1   1  2013-06-16     32.0     29.0  Tomato Small        29.0
# 2   2  2013-06-16     21.0     20.5    Potato Red        20.5
# 3   3  2013-06-16     16.0     15.5  Potato White        15.5
# 4   4  2013-06-16     30.0     29.0    Onion Dry         29.0

# %%
df = df.iloc[:, [0,4,5,2,1]]

# %%
df
# Out:
#             SN            Product  Weight(kg)  Maximum        Date
# 0            0         Tomato Big        37.5     40.0  2013-06-16
# 1            1       Tomato Small        29.0     32.0  2013-06-16
# 2            2         Potato Red        20.5     21.0  2013-06-16
# 3            3       Potato White        15.5     16.0  2013-06-16
# 4            4         Onion Dry         29.0     30.0  2013-06-16
# ...        ...                ...         ...      ...         ...
# 197156  197156  Garlic Dry Nepali       110.0    120.0  2021-05-13
# 197157  197157         Fish Fresh       275.0    280.0  2021-05-13
# 197158  197158         Fish Fresh       230.0    235.0  2021-05-13
# 197159  197159         Fish Fresh       225.0    230.0  2021-05-13
# 197160  197160         Fish Fresh       245.0    250.0  2021-05-13
#
# [197161 rows x 5 columns]

# %%
#df = df.drop(df.columns[[4]], axis=1)

# %%
df.head()
# Out:
#    SN       Product  Weight(kg)  Maximum        Date
# 0   0    Tomato Big        37.5     40.0  2013-06-16
# 1   1  Tomato Small        29.0     32.0  2013-06-16
# 2   2    Potato Red        20.5     21.0  2013-06-16
# 3   3  Potato White        15.5     16.0  2013-06-16
# 4   4    Onion Dry         29.0     30.0  2013-06-16

# %%
import datetime as dt
df['Arrival'] = df['Date'].apply(lambda x:dt.datetime.strptime(x, '%Y-%m-%d'))
df['Arrival'] = df['Date']

# %%
df = df.drop(df.columns[[4]], axis=1)
df
# Out:
#             SN            Product  Weight(kg)  Maximum     Arrival
# 0            0         Tomato Big        37.5     40.0  2013-06-16
# 1            1       Tomato Small        29.0     32.0  2013-06-16
# 2            2         Potato Red        20.5     21.0  2013-06-16
# 3            3       Potato White        15.5     16.0  2013-06-16
# 4            4         Onion Dry         29.0     30.0  2013-06-16
# ...        ...                ...         ...      ...         ...
# 197156  197156  Garlic Dry Nepali       110.0    120.0  2021-05-13
# 197157  197157         Fish Fresh       275.0    280.0  2021-05-13
# 197158  197158         Fish Fresh       230.0    235.0  2021-05-13
# 197159  197159         Fish Fresh       225.0    230.0  2021-05-13
# 197160  197160         Fish Fresh       245.0    250.0  2021-05-13
#
# [197161 rows x 5 columns]

# %%
df.head()
# Out:
#    SN       Product  Weight(kg)  Maximum     Arrival
# 0   0    Tomato Big        37.5     40.0  2013-06-16
# 1   1  Tomato Small        29.0     32.0  2013-06-16
# 2   2    Potato Red        20.5     21.0  2013-06-16
# 3   3  Potato White        15.5     16.0  2013-06-16
# 4   4    Onion Dry         29.0     30.0  2013-06-16

# %%
df['BestBefore'] = df['Arrival'] + pd.DateOffset(days=6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[331], line 1
# ----> 1 df['BestBefore'] = df['Arrival'] + pd.DateOffset(days=6)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\arraylike.py:186, in OpsMixin.__add__(self, other)
#      98 @unpack_zerodim_and_defer("__add__")
#      99 def __add__(self, other):
#     100     """
#     101     Get Addition of DataFrame and other, column-wise.
#     102
#    (...)
#     184     moose     3.0     NaN
#     185     """
# --> 186     return self._arith_method(other, operator.add)
#
# ...

# %%
df.head()
# Out:
#    SN       Product  Weight(kg)  Maximum     Arrival
# 0   0    Tomato Big        37.5     40.0  2013-06-16
# 1   1  Tomato Small        29.0     32.0  2013-06-16
# 2   2    Potato Red        20.5     21.0  2013-06-16
# 3   3  Potato White        15.5     16.0  2013-06-16
# 4   4    Onion Dry         29.0     30.0  2013-06-16

# %%
import random
namecsv = pd.read_csv("Indian_Names.csv")
names = namecsv.Name.values.tolist()
# random.shuffle(names)
# name =  names[0:31]
# print(name)

# %%
food = ['Tomato Big','Tomato Small','Potato Red','Potato White','Onion Dry','Carrot', 'Cauli', 'Raddish Red', 'Okara', 'Brinjal Long', 'Bringal Long', 'Banana','Apple', 'Lime', 'Jack Fruit', 'Mango', 'Grapes', 'Brocauli', 'Papaya', 'Garlic']

# %%
df["Item"] = df['Product'].apply(lambda x: x if x in food else 0 )

# %%
df1 = df[df['Item'] != 0]

# %%
# df1 = df1.reset_index()

# %%
# del df1['SN']

# %%
# del df1['index']
# del df1['level_0']
# del df1['Item']

# %%
# df1 = df1.reset_index()

# %%
df1.count()
# Out:
# SN            39461
# Product       39461
# Weight(kg)    39461
# Maximum       39461
# Date          39461
# Arrival       39461
# BestBefore    39461
# Item          39461
# dtype: int64

# %%
namecsv['id'] = namecsv[['Name']].sum(axis=1).map(hash)

# %%
namecsv1 = namecsv.sample(30)
namecsv1
# Out:
#       Unnamed: 0      Name                   id
# 8              8   aafreen  -551849167597184396
# 3100        3100   masheen -1788536845264861687
# 362          362    anjana  1232051158173452214
# 3787        3787    ombeer -1352217621921621920
# 2278        2278    jhumki  1431461805276358659
# 6062        6062     teena -4742464532951854610
# 3352        3352    mukund -1306070675347471845
# 5884        5884    sunita -8822692391735875263
# 2274        2274     jhora -2520443885888386071
# 1989        1989     ilesh -8258597296620904771
# 1097        1097    chnada -9190955255248478031
# 3816        3816     padam -4442836798526717483
# 3608        3608     nazia -7448081505234321652
# 5922        5922       sus  6578905927223745668
# 2264        2264    jhaban  3647098995629111519
# 6287        6287     vidha  6214184028727407421
# 1330        1330    dildar  2160220897318226755
# 125          125     adesh  8826514149384637484
# 302          302      amot -4492399128159667283
# ...

# %%
namecsv1 = namecsv1.reset_index()

# %%
del namecsv1['Unnamed: 0']
namecsv1.head(30)
# Out:
#     index      Name                   id
# 0       8   aafreen  -551849167597184396
# 1    3100   masheen -1788536845264861687
# 2     362    anjana  1232051158173452214
# 3    3787    ombeer -1352217621921621920
# 4    2278    jhumki  1431461805276358659
# 5    6062     teena -4742464532951854610
# 6    3352    mukund -1306070675347471845
# 7    5884    sunita -8822692391735875263
# 8    2274     jhora -2520443885888386071
# 9    1989     ilesh -8258597296620904771
# 10   1097    chnada -9190955255248478031
# 11   3816     padam -4442836798526717483
# 12   3608     nazia -7448081505234321652
# 13   5922       sus  6578905927223745668
# 14   2264    jhaban  3647098995629111519
# 15   6287     vidha  6214184028727407421
# 16   1330    dildar  2160220897318226755
# 17    125     adesh  8826514149384637484
# 18    302      amot -4492399128159667283
# 19   4271   rajbeer  -109948124761560060
# 20   3294     monny  4455993159020929908
# 21   3713   nirutma  7323523933125748901
# ...

# %%
# del namecsv1['index']
namecsv1
# Out:
#     index      Name                   id
# 0       8   aafreen  -551849167597184396
# 1    3100   masheen -1788536845264861687
# 2     362    anjana  1232051158173452214
# 3    3787    ombeer -1352217621921621920
# 4    2278    jhumki  1431461805276358659
# 5    6062     teena -4742464532951854610
# 6    3352    mukund -1306070675347471845
# 7    5884    sunita -8822692391735875263
# 8    2274     jhora -2520443885888386071
# 9    1989     ilesh -8258597296620904771
# 10   1097    chnada -9190955255248478031
# 11   3816     padam -4442836798526717483
# 12   3608     nazia -7448081505234321652
# 13   5922       sus  6578905927223745668
# 14   2264    jhaban  3647098995629111519
# 15   6287     vidha  6214184028727407421
# 16   1330    dildar  2160220897318226755
# 17    125     adesh  8826514149384637484
# 18    302      amot -4492399128159667283
# 19   4271   rajbeer  -109948124761560060
# 20   3294     monny  4455993159020929908
# 21   3713   nirutma  7323523933125748901
# ...

# %%
df1.head()
# Out:
#    SN       Product  Weight(kg)  Maximum        Date    Arrival BestBefore  \
# 0   0    Tomato Big        37.5     40.0  2013-06-16 2013-06-16 2013-06-22
# 1   1  Tomato Small        29.0     32.0  2013-06-16 2013-06-16 2013-06-22
# 2   2    Potato Red        20.5     21.0  2013-06-16 2013-06-16 2013-06-22
# 3   3  Potato White        15.5     16.0  2013-06-16 2013-06-16 2013-06-22
# 5   5        Carrot        32.5     35.0  2013-06-16 2013-06-16 2013-06-22
#
#            Item
# 0    Tomato Big
# 1  Tomato Small
# 2    Potato Red
# 3  Potato White
# 5        Carrot

# %%
import random
namecsv1_shuffled = namecsv1.sample(frac=1,random_state=42)
num_repeats=len(namecsv1_shuffled)//len(df1)+1
df1_repeated=pd.concat([namecsv1]*num_repeats,ignore_index=True)
merged_data=pd.concat([namecsv1_shuffled,df1_repeated],axis=1)
# merged_data=merged_data[["Name","id"]]

# %%
namecsv1_shuffled
# Out:
#     index      Name                   id
# 27   4272    rajbir -7879961416724222237
# 15   6287     vidha  6214184028727407421
# 23   2939     maina  9098842655344112088
# 17    125     adesh  8826514149384637484
# 8    2274     jhora -2520443885888386071
# 9    1989     ilesh -8258597296620904771
# 28   1102    chootu  5594349529289266441
# 24   4954    samima  -312312739111763734
# 12   3608     nazia -7448081505234321652
# 0       8   aafreen  -551849167597184396
# 4    2278    jhumki  1431461805276358659
# 16   1330    dildar  2160220897318226755
# 5    6062     teena -4742464532951854610
# 13   5922       sus  6578905927223745668
# 11   3816     padam -4442836798526717483
# 22    766  bhagwati -6482969708641621668
# 1    3100   masheen -1788536845264861687
# 2     362    anjana  1232051158173452214
# 25   3688      nila   560877901209599871
# 3    3787    ombeer -1352217621921621920
# 21   3713   nirutma  7323523933125748901
# 26   3444     nagma -2510840795701807709
# ...

# %%
num_rows = 40000
num_duplicates = num_rows // namecsv1.shape[0]  
remainder_rows = num_rows % namecsv1.shape[0]
duplicated_dfs = [namecsv1.sample(n=namecsv1.shape[0], replace=True) for _ in range(num_duplicates)]
if remainder_rows > 0:
    remainder_df = namecsv1.sample(n=remainder_rows, replace=True)
    duplicated_dfs.append(remainder_df)
final_df = pd.concat(duplicated_dfs, ignore_index=True)

# %%
ff = df1.join(final_df)

# %%
ff = ff.reset_index()

# %%
ff
# Out:
#        level_0      SN       Product  Weight(kg)  Maximum        Date  \
# 0            0       0    Tomato Big        37.5     40.0  2013-06-16
# 1            1       1  Tomato Small        29.0     32.0  2013-06-16
# 2            2       2    Potato Red        20.5     21.0  2013-06-16
# 3            3       3  Potato White        15.5     16.0  2013-06-16
# 4            5       5        Carrot        32.5     35.0  2013-06-16
# ...        ...     ...           ...         ...      ...         ...
# 39456   197133  197133         Mango       145.0    150.0  2021-05-13
# 39457   197134  197134        Grapes       225.0    250.0  2021-05-13
# 39458   197140  197140    Jack Fruit        45.0     50.0  2021-05-13
# 39459   197142  197142        Papaya        65.0     70.0  2021-05-13
# 39460   197143  197143        Papaya       105.0    110.0  2021-05-13
#
#          Arrival BestBefore          Item   index    Name            id
# ...

# %%
ff = ff.reindex(columns=['Name', 'id', 'Product', 'Weight(kg)', 'Arrival', 'BestBefore'])
ff
# Out:
#          Name            id       Product  Weight(kg)    Arrival BestBefore
# 0        amot -4.492399e+18    Tomato Big        37.5 2013-06-16 2013-06-22
# 1      anjana  1.232051e+18  Tomato Small        29.0 2013-06-16 2013-06-22
# 2      anjana  1.232051e+18    Potato Red        20.5 2013-06-16 2013-06-22
# 3      rajbir -7.879961e+18  Potato White        15.5 2013-06-16 2013-06-22
# 4       jhora -2.520444e+18        Carrot        32.5 2013-06-16 2013-06-22
# ...       ...           ...           ...         ...        ...        ...
# 39456     NaN           NaN         Mango       145.0 2021-05-13 2021-05-19
# 39457     NaN           NaN        Grapes       225.0 2021-05-13 2021-05-19
# 39458     NaN           NaN    Jack Fruit        45.0 2021-05-13 2021-05-19
# 39459     NaN           NaN        Papaya        65.0 2021-05-13 2021-05-19
# 39460     NaN           NaN        Papaya       105.0 2021-05-13 2021-05-19
#
# [39461 rows x 6 columns]

# %%
file_name = 'Farmer_data1.csv'
ff.to_csv(file_name, index=False)

# %%
ff.head(100)
# Out:
#        Name            id       Product  Weight(kg)    Arrival BestBefore
# 0      amot -4.492399e+18    Tomato Big        37.5 2013-06-16 2013-06-22
# 1    anjana  1.232051e+18  Tomato Small        29.0 2013-06-16 2013-06-22
# 2    anjana  1.232051e+18    Potato Red        20.5 2013-06-16 2013-06-22
# 3    rajbir -7.879961e+18  Potato White        15.5 2013-06-16 2013-06-22
# 4     jhora -2.520444e+18        Carrot        32.5 2013-06-16 2013-06-22
# ..      ...           ...           ...         ...        ...        ...
# 95   rajbir -7.879961e+18        Papaya        57.5 2013-06-21 2013-06-27
# 96    abash  3.195916e+18    Tomato Big        32.5 2013-06-25 2013-07-01
# 97   chootu  5.594350e+18  Tomato Small        27.5 2013-06-25 2013-07-01
# 98   jhumki  1.431462e+18    Potato Red        24.0 2013-06-25 2013-07-01
# 99  rajbeer -1.099481e+17  Potato White        17.5 2013-06-25 2013-07-01
#
# [100 rows x 6 columns]

# %%
df
# Out:
#             SN            Product  Weight(kg)  Maximum     Arrival
# 0            0         Tomato Big        37.5     40.0  2013-06-16
# 1            1       Tomato Small        29.0     32.0  2013-06-16
# 2            2         Potato Red        20.5     21.0  2013-06-16
# 3            3       Potato White        15.5     16.0  2013-06-16
# 4            4         Onion Dry         29.0     30.0  2013-06-16
# ...        ...                ...         ...      ...         ...
# 197156  197156  Garlic Dry Nepali       110.0    120.0  2021-05-13
# 197157  197157         Fish Fresh       275.0    280.0  2021-05-13
# 197158  197158         Fish Fresh       230.0    235.0  2021-05-13
# 197159  197159         Fish Fresh       225.0    230.0  2021-05-13
# 197160  197160         Fish Fresh       245.0    250.0  2021-05-13
#
# [197161 rows x 5 columns]

# %%
df1
# Out:
#             SN       Product  Weight(kg)  Maximum     Arrival          Item
# 0            0    Tomato Big        37.5     40.0  2013-06-16    Tomato Big
# 1            1  Tomato Small        29.0     32.0  2013-06-16  Tomato Small
# 2            2    Potato Red        20.5     21.0  2013-06-16    Potato Red
# 3            3  Potato White        15.5     16.0  2013-06-16  Potato White
# 5            5        Carrot        32.5     35.0  2013-06-16        Carrot
# ...        ...           ...         ...      ...         ...           ...
# 197133  197133         Mango       145.0    150.0  2021-05-13         Mango
# 197134  197134        Grapes       225.0    250.0  2021-05-13        Grapes
# 197140  197140    Jack Fruit        45.0     50.0  2021-05-13    Jack Fruit
# 197142  197142        Papaya        65.0     70.0  2021-05-13        Papaya
# 197143  197143        Papaya       105.0    110.0  2021-05-13        Papaya
#
# [39461 rows x 6 columns]

# %%
dfr = df1.reset_index()
dfr
# Out:
#         index      SN       Product  Weight(kg)  Maximum     Arrival  \
# 0           0       0    Tomato Big        37.5     40.0  2013-06-16
# 1           1       1  Tomato Small        29.0     32.0  2013-06-16
# 2           2       2    Potato Red        20.5     21.0  2013-06-16
# 3           3       3  Potato White        15.5     16.0  2013-06-16
# 4           5       5        Carrot        32.5     35.0  2013-06-16
# ...       ...     ...           ...         ...      ...         ...
# 39456  197133  197133         Mango       145.0    150.0  2021-05-13
# 39457  197134  197134        Grapes       225.0    250.0  2021-05-13
# 39458  197140  197140    Jack Fruit        45.0     50.0  2021-05-13
# 39459  197142  197142        Papaya        65.0     70.0  2021-05-13
# 39460  197143  197143        Papaya       105.0    110.0  2021-05-13
#
#                Item
# 0        Tomato Big
# 1      Tomato Small
# 2        Potato Red
# 3      Potato White
# 4            Carrot
# ...

# %%
df2 = dfr["Maximum"]
df2
# Out:
# 0         40.0
# 1         32.0
# 2         21.0
# 3         16.0
# 4         35.0
#          ...
# 39456    150.0
# 39457    250.0
# 39458     50.0
# 39459     70.0
# 39460    110.0
# Name: Maximum, Length: 39461, dtype: float64

# %%
f
# Out:
#             Name                   id       Product  Weight(kg)     Arrival  \
# 0        shefali -2298907791602927432    Tomato Big        37.5  2013-06-16
# 1        anushka -3763883785994142627  Tomato Small        29.0  2013-06-16
# 2         mehtab -7306772913005020966    Potato Red        20.5  2013-06-16
# 3          mercy -5690939918981728182  Potato White        15.5  2013-06-16
# 4         mehnaz -6840582954423772625        Carrot        32.5  2013-06-16
# ...          ...                  ...           ...         ...         ...
# 39456    sanjeev  2699564478308651307         Mango       145.0  2021-05-13
# 39457  rampayari  2968148604061203207        Grapes       225.0  2021-05-13
# 39458      pinky  -788253433629545359    Jack Fruit        45.0  2021-05-13
# 39459    anushka -3763883785994142627        Papaya        65.0  2021-05-13
# 39460      patik  2723030288162985091        Papaya       105.0  2021-05-13
#
#        BestBefore
# 0      2013-06-22
# ...

# %%
result = pd.concat([f, df2], axis=1)

# %%
result
# Out:
#             Name                   id       Product  Weight(kg)     Arrival  \
# 0        shefali -2298907791602927432    Tomato Big        37.5  2013-06-16
# 1        anushka -3763883785994142627  Tomato Small        29.0  2013-06-16
# 2         mehtab -7306772913005020966    Potato Red        20.5  2013-06-16
# 3          mercy -5690939918981728182  Potato White        15.5  2013-06-16
# 4         mehnaz -6840582954423772625        Carrot        32.5  2013-06-16
# ...          ...                  ...           ...         ...         ...
# 39456    sanjeev  2699564478308651307         Mango       145.0  2021-05-13
# 39457  rampayari  2968148604061203207        Grapes       225.0  2021-05-13
# 39458      pinky  -788253433629545359    Jack Fruit        45.0  2021-05-13
# 39459    anushka -3763883785994142627        Papaya        65.0  2021-05-13
# 39460      patik  2723030288162985091        Papaya       105.0  2021-05-13
#
#        BestBefore  Maximum
# 0      2013-06-22     40.0
# ...

# %%
file_name = 'Farmer_dataPRICE.csv'
result.to_csv(file_name, index=False)

# %%
df2 = df[["Product","Maximum"]]

# %%
df2
# Out:
#                   Product  Maximum
# 0              Tomato Big     40.0
# 1            Tomato Small     32.0
# 2              Potato Red     21.0
# 3            Potato White     16.0
# 4              Onion Dry      30.0
# ...                   ...      ...
# 197156  Garlic Dry Nepali    120.0
# 197157         Fish Fresh    280.0
# 197158         Fish Fresh    235.0
# 197159         Fish Fresh    230.0
# 197160         Fish Fresh    250.0
#
# [197161 rows x 2 columns]

# %%
df2["Price"] = df[["Maximum"]]
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_58032\297801975.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Price"] = df[["Maximum"]]

# %%
df2
# Out:
#                   Product  Maximum
# 0              Tomato Big     40.0
# 1            Tomato Small     32.0
# 2              Potato Red     21.0
# 3            Potato White     16.0
# 4              Onion Dry      30.0
# ...                   ...      ...
# 197156  Garlic Dry Nepali    120.0
# 197157         Fish Fresh    280.0
# 197158         Fish Fresh    235.0
# 197159         Fish Fresh    230.0
# 197160         Fish Fresh    250.0
#
# [197161 rows x 2 columns]

# %%
del df2['Maximum']

# %%
df2
# Out:
#                   Product  Maximum
# 0              Tomato Big     40.0
# 1            Tomato Small     32.0
# 2              Potato Red     21.0
# 3            Potato White     16.0
# 4              Onion Dry      30.0
# ...                   ...      ...
# 197156  Garlic Dry Nepali    120.0
# 197157         Fish Fresh    280.0
# 197158         Fish Fresh    235.0
# 197159         Fish Fresh    230.0
# 197160         Fish Fresh    250.0
#
# [197161 rows x 2 columns]

# %%
food = ['Tomato Big','Tomato Small','Potato Red','Potato White','Onion Dry','Carrot', 'Cauli', 'Raddish Red', 'Okara', 'Brinjal Long', 'Bringal Long', 'Banana','Apple', 'Lime', 'Jack Fruit', 'Mango', 'Grapes', 'Brocauli', 'Papaya', 'Garlic']

# %%
df["Item"] = df['Product'].apply(lambda x: x if x in food else 0 )

# %%
f = pd.read_csv("Farmer_data.csv")

# %%
f
# Out:
#             Name                   id       Product  Weight(kg)     Arrival  \
# 0        shefali -2298907791602927432    Tomato Big        37.5  2013-06-16
# 1        anushka -3763883785994142627  Tomato Small        29.0  2013-06-16
# 2         mehtab -7306772913005020966    Potato Red        20.5  2013-06-16
# 3          mercy -5690939918981728182  Potato White        15.5  2013-06-16
# 4         mehnaz -6840582954423772625        Carrot        32.5  2013-06-16
# ...          ...                  ...           ...         ...         ...
# 39456    sanjeev  2699564478308651307         Mango       145.0  2021-05-13
# 39457  rampayari  2968148604061203207        Grapes       225.0  2021-05-13
# 39458      pinky  -788253433629545359    Jack Fruit        45.0  2021-05-13
# 39459    anushka -3763883785994142627        Papaya        65.0  2021-05-13
# 39460      patik  2723030288162985091        Papaya       105.0  2021-05-13
#
#        BestBefore
# 0      2013-06-22
# ...

# %%
dd = df1["Maximum"]

# %%
dd.tail()
# Out:
# 197133    150.0
# 197134    250.0
# 197140     50.0
# 197142     70.0
# 197143    110.0
# Name: Maximum, dtype: float64

# %%
# Out:
#             Name                   id       Product  Weight(kg)     Arrival  \
# 0        shefali -2298907791602927432    Tomato Big        37.5  2013-06-16
# 1        anushka -3763883785994142627  Tomato Small        29.0  2013-06-16
# 2         mehtab -7306772913005020966    Potato Red        20.5  2013-06-16
# 3          mercy -5690939918981728182  Potato White        15.5  2013-06-16
# 4         mehnaz -6840582954423772625        Carrot        32.5  2013-06-16
# ...          ...                  ...           ...         ...         ...
# 39456    sanjeev  2699564478308651307         Mango       145.0  2021-05-13
# 39457  rampayari  2968148604061203207        Grapes       225.0  2021-05-13
# 39458      pinky  -788253433629545359    Jack Fruit        45.0  2021-05-13
# 39459    anushka -3763883785994142627        Papaya        65.0  2021-05-13
# 39460      patik  2723030288162985091        Papaya       105.0  2021-05-13
#
#        BestBefore
# 0      2013-06-22
# ...

# %%
dd
# Out:
# 0          40.0
# 1          32.0
# 2          21.0
# 3          16.0
# 5          35.0
#           ...
# 197133    150.0
# 197134    250.0
# 197140     50.0
# 197142     70.0
# 197143    110.0
# Name: Maximum, Length: 39461, dtype: float64

# %%
result = pd.concat([f, dd], axis=1)

# %%
result
# Out:
#            Name            id       Product  Weight(kg)     Arrival  \
# 0       shefali -2.298908e+18    Tomato Big        37.5  2013-06-16
# 1       anushka -3.763884e+18  Tomato Small        29.0  2013-06-16
# 2        mehtab -7.306773e+18    Potato Red        20.5  2013-06-16
# 3         mercy -5.690940e+18  Potato White        15.5  2013-06-16
# 4        mehnaz -6.840583e+18        Carrot        32.5  2013-06-16
# ...         ...           ...           ...         ...         ...
# 197133      NaN           NaN           NaN         NaN         NaN
# 197134      NaN           NaN           NaN         NaN         NaN
# 197140      NaN           NaN           NaN         NaN         NaN
# 197142      NaN           NaN           NaN         NaN         NaN
# 197143      NaN           NaN           NaN         NaN         NaN
#
#         BestBefore  Maximum
# 0       2013-06-22     40.0
# 1       2013-06-22     32.0
# 2       2013-06-22     21.0
# 3       2013-06-22     16.0
# ...

# %%
f
# Out:
#             Name                   id       Product  Weight(kg)     Arrival  \
# 0        shefali -2298907791602927432    Tomato Big        37.5  2013-06-16
# 1        anushka -3763883785994142627  Tomato Small        29.0  2013-06-16
# 2         mehtab -7306772913005020966    Potato Red        20.5  2013-06-16
# 3          mercy -5690939918981728182  Potato White        15.5  2013-06-16
# 4         mehnaz -6840582954423772625        Carrot        32.5  2013-06-16
# ...          ...                  ...           ...         ...         ...
# 39456    sanjeev  2699564478308651307         Mango       145.0  2021-05-13
# 39457  rampayari  2968148604061203207        Grapes       225.0  2021-05-13
# 39458      pinky  -788253433629545359    Jack Fruit        45.0  2021-05-13
# 39459    anushka -3763883785994142627        Papaya        65.0  2021-05-13
# 39460      patik  2723030288162985091        Papaya       105.0  2021-05-13
#
#        BestBefore
# 0      2013-06-22
# ...
